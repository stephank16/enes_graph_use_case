# %%
# !pip install --upgrade ipython-cypher
# Out:
# Requirement already up-to-date: ipython-cypher in /home/stephan/.conda/envs/generic1/lib/python2.7/site-packages
# Requirement already up-to-date: neo4jrestclient>=2.1.0 in /home/stephan/.conda/envs/generic1/lib/python2.7/site-packages (from ipython-cypher)
# ...
#     100% |████████████████████████████████| 747kB 1.1MB/s
# Requirement already up-to-date: prettytable in /home/stephan/.conda/envs/generic1/lib/python2.7/site-packages (from ipython-cypher)
# ...
#     100% |████████████████████████████████| 522kB 1.6MB/s
# ...
#     100% |████████████████████████████████| 757kB 1.0MB/s
# ...
# Requirement already up-to-date: simplegeneric>0.8 in /home/stephan/.conda/envs/generic1/lib/python2.7/site-packages (from ipython>=1.0->ipython-cypher)
# ...
#     100% |████████████████████████████████| 71kB 8.5MB/s
# ...
#     100% |████████████████████████████████| 450kB 1.4MB/s
# ...
#     100% |████████████████████████████████| 61kB 3.3MB/s
# ...
#     100% |████████████████████████████████| 256kB 3.3MB/s
# ...
